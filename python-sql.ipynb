# %%
import pandas as pd

df= pd.read_csv("population_by_country_2020.csv")

# %%
df= df.head(201)
df
# Out:
#     Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 0                     China         1438207241        0.39 %     5540090
# 1                     India         1377233523        0.99 %    13586631
# 2             United States          330610570        0.59 %     1937734
# 3                 Indonesia          272931713        1.07 %     2898047
# 4                  Pakistan          219992900        2.00 %     4327022
# ..                      ...                ...           ...         ...
# 196                   Aruba             106675        0.43 %         452
# 197                   Tonga             105449        1.15 %        1201
# 198     U.S. Virgin Islands             104456       -0.15 %        -153
# 199              Seychelles              98224        0.62 %         608
# 200     Antigua and Barbuda              97764        0.84 %         811
#
#      Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# ...

# %%
df.columns
# Out:
# Index(['Country (or dependency)', 'Population (2020)', 'Yearly Change',
#        'Net Change', 'Density (P/Km²)', 'Land Area (Km²)', 'Migrants (net)',
#        'Fert. Rate', 'Med. Age', 'Urban Pop %', 'World Share'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Population (2020)    Net Change  Density (P/Km²)  Land Area (Km²)  \
# count       2.010000e+02  2.010000e+02       201.000000     2.010000e+02
# mean        3.869072e+07  4.046024e+05       358.626866     6.450903e+05
# std         1.452155e+08  1.210617e+06      1710.115498     1.809408e+06
# min         9.776400e+04 -3.838400e+05         2.000000     3.000000e+01
# 25%         1.890218e+06  3.786000e+03        34.000000     2.164000e+04
# 50%         8.627444e+06  6.040300e+04        89.000000     1.085600e+05
# 75%         2.753911e+07  3.602040e+05       226.000000     4.988000e+05
# max         1.438207e+09  1.358663e+07     21645.000000     1.637687e+07
#
#        Migrants (net)
# count      201.000000
# mean         6.283582
# std     123291.887548
# min    -653249.000000
# 25%     -10047.000000
# 50%       -852.000000
# 75%       9741.000000
# max     954806.000000

# %%
df.head()
# Out:
#   Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 0                   China         1438207241        0.39 %     5540090
# 1                   India         1377233523        0.99 %    13586631
# 2           United States          330610570        0.59 %     1937734
# 3               Indonesia          272931713        1.07 %     2898047
# 4                Pakistan          219992900        2.00 %     4327022
#
#    Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 0              153          9388211       -348399.0        1.7       38
# 1              464          2973190       -532687.0        2.2       28
# 2               36          9147420        954806.0        1.8       38
# 3              151          1811570        -98955.0        2.3       30
# 4              287           770880       -233379.0        3.6       23
#
#   Urban Pop % World Share
# 0        61 %     18.47 %
# 1        35 %     17.70 %
# ...

# %%
df.tail()
# Out:
#     Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 196                   Aruba             106675        0.43 %         452
# 197                   Tonga             105449        1.15 %        1201
# 198     U.S. Virgin Islands             104456       -0.15 %        -153
# 199              Seychelles              98224        0.62 %         608
# 200     Antigua and Barbuda              97764        0.84 %         811
#
#      Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 196              593              180           201.0        1.9       41
# 197              147              720          -800.0        3.6       22
# 198              298              350          -451.0        2.0       43
# 199              214              460          -200.0        2.5       34
# 200              223              440             0.0        2.0       34
#
#     Urban Pop % World Share
# 196        44 %      0.00 %
# ...

# %%
df[df["Population (2020)"]> 10 ** 9]
# Out:
#   Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 0                   China         1438207241        0.39 %     5540090
# 1                   India         1377233523        0.99 %    13586631
#
#    Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 0              153          9388211       -348399.0        1.7       38
# 1              464          2973190       -532687.0        2.2       28
#
#   Urban Pop % World Share
# 0        61 %     18.47 %
# 1        35 %     17.70 %

# %%
med_age = pd.to_numeric(df["Med. Age"])
df[med_age < 30 ].sort_values('Country (or dependency)', ascending= True)
# Out:
#     Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 36              Afghanistan           38742911        2.33 %      886592
# 32                  Algeria           43685618        1.85 %      797990
# 43                   Angola           32644783        3.27 %     1040977
# 7                Bangladesh          164354176        1.01 %     1643222
# 176                  Belize             396120        1.86 %        7275
# ..                      ...                ...           ...         ...
# 180                 Vanuatu             305623        2.42 %        7263
# 169          Western Sahara             594215        2.55 %       14876
# 47                    Yemen           29687214        2.28 %      664042
# 64                   Zambia           18273379        2.93 %      522925
# 73                 Zimbabwe           14818157        1.48 %      217456
#
#      Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# ...

# %%
df=df.head(30)

df.plot(kind="pie", y= "Population (2020)", labels= df["Country (or dependency)"], figsize=(20, 40), startangle=90, legend=True, fontsize=8)
